# %%
import torch
import torch.nn as nn

# %%
a = torch.rand((2, 1, 50))
print(a)
# Out:
# tensor([[[0.4053, 0.8384, 0.8845, 0.3450, 0.5601, 0.2682, 0.5579, 0.9222,
#           0.6865, 0.6492, 0.5396, 0.3679, 0.8037, 0.9810, 0.7539, 0.3457,
#           0.0489, 0.7442, 0.3440, 0.2991, 0.7308, 0.4993, 0.0919, 0.4177,
#           0.3644, 0.1243, 0.5220, 0.6042, 0.5260, 0.2942, 0.0328, 0.0841,
#           0.2387, 0.9884, 0.2235, 0.6157, 0.9602, 0.1102, 0.9855, 0.1916,
#           0.2429, 0.1195, 0.2684, 0.8509, 0.1868, 0.5470, 0.0289, 0.1948,
#           0.2275, 0.7619]],
#
#         [[0.7005, 0.7962, 0.4124, 0.6748, 0.7868, 0.5135, 0.1127, 0.8734,
#           0.3285, 0.8532, 0.2293, 0.7333, 0.1378, 0.3595, 0.2532, 0.4838,
#           0.0596, 0.0848, 0.5341, 0.8622, 0.3676, 0.9911, 0.2782, 0.5738,
#           0.2596, 0.0409, 0.3696, 0.6116, 0.3440, 0.7418, 0.3562, 0.0735,
#           0.6986, 0.7330, 0.2210, 0.0416, 0.1902, 0.6053, 0.6907, 0.3503,
#           0.9024, 0.7481, 0.7895, 0.8170, 0.3304, 0.6236, 0.6941, 0.8359,
#           0.0019, 0.6235]]])

# %%
layer = nn.MultiheadAttention(50, 5)

# %%
t, w = layer(a, a, a)

# %%
print(t)
print(w)
# Out:
# tensor([[[-1.4733e-01, -1.0665e-01, -3.1613e-01,  2.4166e-01,  2.4824e-02,
#            1.7984e-02, -1.3288e-01, -1.6287e-02, -1.1943e-01, -2.7139e-01,
#            1.9631e-01,  1.5713e-01,  1.6061e-01,  2.4967e-01,  9.8352e-03,
#           -5.5075e-01,  9.8403e-02,  7.7551e-02,  1.6099e-01, -3.5475e-02,
#           -3.2207e-02,  3.0032e-02,  6.2906e-02, -3.1800e-01,  2.5334e-03,
#            3.7509e-01, -3.2621e-02, -2.3460e-03, -7.6148e-02,  1.2636e-01,
#            5.9419e-02,  1.5884e-01,  5.1762e-01, -2.1821e-01,  1.8214e-01,
#           -4.7175e-02,  1.6807e-01, -9.1662e-02, -4.3998e-02,  9.8483e-02,
#           -3.9125e-01,  1.1457e-01,  3.8700e-01, -2.0767e-01, -3.5879e-01,
#           -3.4666e-01,  3.0591e-02,  4.8508e-01,  8.9583e-02, -3.9627e-02]],
#
#         [[-1.4652e-01, -1.0597e-01, -3.1294e-01,  2.4411e-01,  2.5952e-02,
#            1.7708e-02, -1.2786e-01, -1.5102e-02, -1.1774e-01, -2.7539e-01,
# ...
